# %%
# transformer block

# %%
# transformer block(decoder block)
# combineees multi-head attention, feed-forward networ,layer normalization,ad residual connections 

# Arch 
# x -> layernorm -> MHA -> residual -> layernorm -> feedforward -> residual

# %%
import
