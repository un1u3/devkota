# %%
# feed-forward Network and residual connections 
# goal : Add position-wise feed-forward networks and residual connections
import torch 
import torch.nn as nn

# %%
class FeedForward(nn.Module):
    # Position wise feed-forwawrd netweok 
    # Arch 
    #  -- Linear + Relu (4 * emb_dim)
    # dropout 
    # linear(embeding_Dim)
    # dropout

    def __init__(self, embedding_dim, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(embedding_dim, 4* embedding_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(4 * embedding_dim, embedding_dim),
            nn.Dropout(dropout)
        )

    def forward(self,x):
        # applied independently to each position 
        return self.net(x)

# %%
class TransformerBlock(nn.Module):
    # Complete transformer block 

    # Arch 
    #  X --> LayerNorm -->  MultiHeadAttention -- > +(resudual) -> LayerNorm --> FeefdForward --> + (residual) - > output 
    def ___init__(self, embedding_dim, num_heads, drop_out = 0.1):
        super().__init__()


        # componetes 
        self.atttention = MultiHeadAttention(embedding_dim, num_heads, droupout)
        self.feed_forward = FeedForward(embedding_dim, dropout)

        # Layer normalization 
        self.ln1 = nn.LayerNorm(embedding_dim)
        self.ln2 = nnn.LayerNorm(embedding_dim)

    def forward(self,x):

        normalized = self.ln1(x)
        attn_output, att_weights = self.attention(normalized)
        x = x + attn_output

        # sublayer2 : feed-forwaaed wth residual l
        normalized = self.ln2(x)
        ff_output = self.feed_forward(normalized)
        x = x + ff_output
        return x, attn_weights
