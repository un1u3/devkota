# %%
# 01 paradigm
# mar 26 
# build the morpholofical paradigm for nepali

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/paradigm.csv')

# %%
df['verified'] = 'YES'
df.to_csv('../data/paradigm.csv',index=False)

# %%
# verified all datasources that it is correct 
# 150 entries in total
# 5 verb stems x 24
# 5 noun stems x 6

# %%
print(f"Total entries: {len(df)}")
print(df.head(10))
# Out:
# Total entries: 150
#   stem stem_nepali          slot surface_form                    gloss  \
# 0  gar         गर्      1SG.PRES        गर्छु                     I do
# 1  gar         गर्      2SG.PRES       गर्छस्        you do (informal)
# 2  gar         गर्  2SG.PRES.MID        गर्छौ        you do (friendly)
# 3  gar         गर्      3SG.PRES         गर्छ              he/she does
# 4  gar         गर्      1PL.PRES       गर्छौं                    we do
# 5  gar         गर्      2PL.PRES        गर्छौ               you all do
# 6  gar         गर्      3PL.PRES       गर्छन्                  they do
# 7  gar         गर्     2HON.PRES   गर्नुहुन्छ       you do (honorific)
# 8  gar         गर्     3HON.PRES   गर्नुहुन्छ  he/she does (honorific)
# 9  gar         गर्      1SG.PAST         गरें                    I did
#
#   verified
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4      YES
# 5      YES
# 6      YES
# 7      YES
# 8      YES
# 9      YES
